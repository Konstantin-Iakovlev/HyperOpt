# %%
import json
import matplotlib.pylab as plt
with open('luketina_0_traj.json') as inp:
    datal = json.loads(inp.read())
with open('IFT_10_0_traj.json') as inp:
    datai = json.loads(inp.read())
plt.plot(np.log(datal['0'][0]), label='luk')
plt.plot(np.log(datai['0'][0]), label='proposed')
plt.legend(loc='best')

# %%
plt.plot(datal['0'][10:], label='luk')
plt.plot(datai['0'][10:], label='proposed')

# %%
import numpy as np
x = -2.7178362e-07
x**2 - 10 * np.cos(2 * np.pi * x) + 10
jnp = np
10 - 10 * jnp.cos(2 * jnp.pi * x)  + x**2
# Out:
# 1.465420327389756e-11
